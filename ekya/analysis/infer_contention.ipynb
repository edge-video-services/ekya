# %%
import matplotlib.pyplot as plt
import csv
import numpy as np
import pandas as pd
import pickle
import base64
from collections import defaultdict
import glob
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams.update({'font.size':20})

def make_patch_spines_invisible(ax):
    ax.set_frame_on(True)
    ax.patch.set_visible(False)
    for sp in ax.spines.values():
        sp.set_visible(False)

# %% [markdown]
# ### Read data

# %%
BASE_DIR = "./data/infer_stress/"
gpu_data = pd.read_csv(BASE_DIR + "node_gpu_0.csv", header=None, names=["timestamp", "id", "load", "memoryTotal", "memoryUsed"])

# %%
start_timestamp = min(data["timestamp"])
infer_latency_data = data["latency"]/data["samples"]
infer_timestamps = data["timestamp"] - start_timestamp
infer_accuracy_data = data["accuracy"]

# %%
infer_files = glob.glob(BASE_DIR + "*_infer_stats.csv")
infer_data = {}
for file_path in infer_files:
    model_id = file_path.split('/')[-1].split('_')[0]
    infer_data[model_id] = pd.read_csv(file_path, header=None, names=["timestamp", "latency", "accuracy", "samples", "datadict"])

# %%
gpu_timestamps = gpu_data["timestamp"]
gpu_load = gpu_data["load"]

# %%
start_timestamp = min([min(d["timestamp"]) for d in infer_data.values()] + [min(gpu_timestamps)])

# %%
fig, ax1 = plt.subplots()
fig.subplots_adjust(right=0.75)

ax2 = ax1.twinx()
ax3 = ax1.twinx()

ax3.spines["right"].set_position(("axes", 1.2))
make_patch_spines_invisible(ax3)
ax3.spines["right"].set_visible(True)

for model_id, data in infer_data.items():
    data["timestamp"]
    p1, = ax1.plot(data["timestamp"] - start_timestamp, data["latency"]/data["samples"], "--", label=str(model_id))
memplot, = ax2.plot(gpu_data["timestamp"] - start_timestamp, gpu_data["memoryUsed"], "r-", label="GPU Mem")
coreplot = ax3.scatter(gpu_data["timestamp"] - start_timestamp, gpu_data["load"], color='g',label="GPU Load")

ax1.set_xlabel("Wall time")
ax1.set_ylabel("Latency (s)")
ax2.set_ylabel("GPU Mem")
ax3.set_ylabel("GPU Core Util")

ax2.yaxis.label.set_color(memplot.get_color())
ax3.yaxis.label.set_color('g')

plt.title("Inference-inference contention test, total jobs before OOM: {}".format(len(infer_data)))

# ax1 = fig.add_subplot(111)
# ax1.plot(infer_timestamps, infer_accuracy_data, marker='*')
# ax1.plot(gpu_timestamps, gpu_load, 'g-')
# # for c, c_data in infer_accuracy_per_class.items():
# #     ax1.plot(infer_timestamps, c_data, marker='*')
# ax1.set_ylabel('infer_accuracy (%)')

# ax2 = ax1.twinx()
# ax2.plot(infer_timestamps, infer_latency_data, 'r-', marker='o')
# ax2.set_ylabel('per sample infer_latency (ms)', color='r')
# for tl in ax2.get_yticklabels():
#     tl.set_color('r')
    
# plt.xlabel("Wall time")
# Out:
# Text(0.5,1,'Inference-inference contention test, total jobs before OOM: 12')

# %% [markdown]
# ### Scaling

# %%
data = infer_data["1"]
job_start_times = sorted([min(data["timestamp"] - start_timestamp) for data in infer_data.values()])
job_ctr = range(1,len(job_start_times)+1)

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

ax1.plot(data["timestamp"] - start_timestamp, data["latency"]/min(data["latency"]))
ax2.plot(job_start_times, job_ctr, 'r-', marker='o')


ax1.set_xlabel("Wall time")
ax1.set_ylabel("Relative Query Latency (x)")
ax1.yaxis.label.set_color('b')
ax2.set_ylabel("Number of inference jobs")
ax2.yaxis.label.set_color('r')
ax1.grid()

ax1.set_ylim([0,14])
ax2.set_ylim([0,14])

plt.title("Query Latency Scaling, inference-inference contention")
plt.plot()
# Out:
# []

# %%
data = infer_data["1"]
job_start_times = sorted([min(data["timestamp"] - start_timestamp) for data in infer_data.values()])
job_ctr = range(1,len(job_start_times)+1)

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax3 = ax1.twinx()

ax3.spines["right"].set_position(("axes", 1.2))
make_patch_spines_invisible(ax3)
ax3.spines["right"].set_visible(True)

ax1.plot(data["timestamp"] - start_timestamp, data["latency"]/min(data["latency"]))
ax2.plot(job_start_times, job_ctr, 'r-', marker='o')
ax3.scatter(gpu_data["timestamp"] - start_timestamp, gpu_data["load"], color='g',label="GPU Load")


ax1.set_xlabel("Wall time")
ax1.set_ylabel("Relative Query Latency (x)")
ax1.yaxis.label.set_color('b')
ax2.set_ylabel("Number of inference jobs")
ax2.yaxis.label.set_color('r')
ax1.grid()
ax3.set_ylabel("GPU Core Util")
ax3.yaxis.label.set_color('g')

ax1.set_ylim([0,14])
ax2.set_ylim([0,14])

plt.title("Query Latency Scaling, inference-inference contention")
plt.plot()
# Out:
# []
